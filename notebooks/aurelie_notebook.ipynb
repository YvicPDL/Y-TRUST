# %%
#Import librairies

import pandas as pd

# %%
df = pd.read_csv('en.openfoodfacts.org.products.csv', sep='\t', engine='python', nrows=50000)
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#    code                                                url  creator  \
# 0    54  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 1    63  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 2   114  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 3     1  http://world-en.openfoodfacts.org/product/0000...      inf
# 4   105  http://world-en.openfoodfacts.org/product/0000...  kiliweb
#
#     created_t      created_datetime  last_modified_t last_modified_datetime  \
# 0  1582569031  2020-02-24T18:30:31Z       1733085204   2024-12-01T20:33:24Z
# 1  1673620307  2023-01-13T14:31:47Z       1746258398   2025-05-03T07:46:38Z
# 2  1580066482  2020-01-26T19:21:22Z       1737247862   2025-01-19T00:51:02Z
# 3  1634745456  2021-10-20T15:57:36Z       1748552638   2025-05-29T21:03:58Z
# 4  1572117743  2019-10-26T19:22:23Z       1738073570   2025-01-28T14:12:50Z
#
#   last_modified_by  last_updated_t last_updated_datetime  \
# ...

# %%
df.origins.unique()
# Out:
# array([nan, 'Spanien', 'île d’Orléans,Québec,Canada', 'Nizozemsko,Peru',
#        'it:mondo', 'fr:Blé origine France,fr:Œufs origine France',
#        'organic defeated hemp seed powder,organic coconut sugar,organic natural flavor',
#        'Argentine', 'en:Non spécifié', 'France', 'Peru', 'USA', 'Pérou',
#        'China', 'fr:colombie', 'Brésil',
#        'UNITED KINGDOM,unit 12,Sefton business Park,Merseyside,L30 1RD',
#        'España', 'Mundo', 'Italy', 'Spain', 'Italien', 'Allemagne',
#        'Palestinian territories', 'Rhône', 'United States', 'Avocat',
#        'Nigeria', 'United Kingdom', 'Union européenne', 'Earth',
#        'Germany', 'pt:proteina isolada frutose', 'Paraguay', 'Argentina',
#        'Deutschland', 'états-unis, it:mondo', 'agriculture biologique',
#        'Fabriqué en France', 'Légumes origine UE', 'ue', 'non connu',
#        'fromages bleu pecorino romano', 'uae', 'Arabie saoudite',
# ...

# %%
df.origins_tags.unique()
# Out:
# array([nan, 'en:spain', 'en:canada,en:quebec,fr:ile-d-orleans',
#        'en:netherlands,en:peru', 'en:world',
#        'fr:ble-origine-france,fr:oeufs-origine-france',
#        'en:organic-coconut-sugar,en:organic-defeated-hemp-seed-powder,en:organic-natural-flavor',
#        'en:argentina', 'en:non-specifie', 'en:france', 'en:peru',
#        'en:united-states', 'en:china', 'en:colombia', 'en:bresil',
#        'en:united-kingdom,en:l30-1rd,en:merseyside,en:sefton-business-park,en:unit-12',
#        'en:italy', 'en:germany', 'en:palestinian-territories', 'rhone',
#        'united-states', 'fr:avocat', 'en:nigeria', 'france',
#        'en:united-kingdom', 'en:european-union', 'en:earth',
#        'pt:proteina-isolada-frutose', 'en:paraguay',
#        'en:united-states,en:world', 'fr:agriculture-biologique',
#        'fr:fabrique-en-france', 'en:legumes-origine-ue', 'fr:non-connu',
#        'en:fromages-bleu-pecorino-romano', 'en:united-arab-emirates',
# ...

# %%
df.origins_en.unique()
# Out:
# array([nan, 'Spain', 'Canada,Québec,fr:ile-d-orleans', 'Netherlands,Peru',
#        'World', 'fr:ble-origine-france,fr:oeufs-origine-france',
#        'Organic-coconut-sugar,Organic-defeated-hemp-seed-powder,Organic-natural-flavor',
#        'Argentina', 'Non-specifie', 'France', 'Peru', 'United States',
#        'China', 'Colombia', 'Bresil',
#        'United Kingdom,L30-1rd,Merseyside,Sefton-business-park,Unit-12',
#        'Italy', 'Germany', 'Palestinian territories', 'Rhône',
#        'fr:avocat', 'Nigeria', 'United Kingdom', 'European Union',
#        'Earth', 'pt:proteina-isolada-frutose', 'Paraguay',
#        'United States,World', 'fr:agriculture-biologique',
#        'fr:fabrique-en-france', 'Legumes-origine-ue', 'fr:non-connu',
#        'Fromages-bleu-pecorino-romano', 'United Arab Emirates',
#        'Saudi Arabia', 'World,es:stati-uniti-d-america', 'Japan',
#        'Greece', 'Coconut', 'sk:london', 'Egypt', 'Uganda',
# ...

# %%
df.labels.unique()
# Out:
# array([nan, 'Point Vert, Fabriqué en France',
#        'No gluten, Organic, Vegetarian, EU Organic, Kosher, No artificial flavors, No preservatives, Vegan, BG-BIO-22, Kosher-parve, Made in Germany, No additives, No lactose, fr:ab-agriculture-biologique',
#        ..., 'Sans gluten, Végétarien, Végétalien, Sans additifs',
#        'Organic, EU Organic, Non-EU Agriculture, EU Agriculture, EU/non-EU Agriculture, FR-BIO-01, Made in Germany, No added sugar, Nutriscore, Nutriscore Grade A, AB Agriculture Biologique, en:certified-b-corporation',
#        'Organic, EU Organic, FR-BIO-01, Made in Italy, en:certified-b-corporation'],
#       dtype=object)

# %%
df.countries.unique()
# Out:
# array(['en:fr', 'France', 'DE', 'Spanien, Germany', 'Brasilien, Germany',
#        'Griechenland, Germany', 'Frankreich, Germany',
#        'Germany, United States, en:france', 'Germany, en:france',
#        'Vereinigte Staaten von Amerika, Germany', 'en:germany, World',
#        'Germany,Spain', 'en:germany', 'Germany', 'en:Switzerland', nan,
#        'Ireland, en:france', 'Irland, Germany', 'en:France', 'Brasil',
#        'Belgien, Germany', 'España', 'United States', 'FR',
#        'European Union', 'en:FR', 'selestosina', 'en:Ireland',
#        'Alemania,España', 'Francia,España', 'United Kingdom',
#        'en:United Kingdom', 'United Kingdom, en:france', 'brasil',
#        'en:Moldova', 'en:Italy', 'Belgium', 'US', 'EG', 'spain',
#        'en:Germany', 'France,Espagne', 'Germany,en:germany', 'comidosil',
#        'france', 'en:United States', 'Exland',
#        'Frankreich, Gabun, Germany', 'Malaysia,Germany,',
# ...

# %%
df.manufacturing_places.unique()
# Out:
# array([nan, 'Ancenis', 'Canada', 'bénivay-ollon', 'France',
#        'Saint-Yrieix,France', 'Argentine', 'uk',
#        'FRANCE,Spain,Italia,Argentina - Español,Aruba - Español,Bolivia - Español,Brazil - Português,Canada - English,Canada - Français,Chile - Español,Colombia - Español,Costa Rica - Español,Ecuador - Español,El Salvador - Español,Guatemala - Español,Honduras - Español,Jamaica - English,Mexico - Español,Nicaragua - Español,Panamá - Español,Paraguay - Español,Perú - Español,Puerto Rico - Español,República Dominicana - Español,Trinidad & Tobago - English,United States - English,United States - Español,Uruguay - Español,Venezuela - Español,Europe,Armenia - Pyсский,Austria - Deutsch,Azerbaijan - Русский,Belarus - Pyсский,Belgium - Français,Belgium - Nederlands',
#        '87500,France', 'USA', 'Fort Worth, TX', 'Allemagne', 'Alicante',
#        'france', 'Italy', 'Good Organics Gmbh', 'Rhône',
#        '87500 Saint Yrieix', 'France,87500', 'United States', 'UK',
# ...

# %%
df.manufacturing_places_tags.unique()
# Out:
# array([nan, 'ancenis', 'canada', 'benivay-ollon', 'france',
#        'saint-yrieix,france', 'argentine', 'uk',
#        'france,spain,italia,argentina-espanol,aruba-espanol,bolivia-espanol,brazil-portugues,canada-english,canada-francais,chile-espanol,colombia-espanol,costa-rica-espanol,ecuador-espanol,el-salvador-espanol,guatemala-espanol,honduras-espanol,jamaica-english,mexico-espanol,nicaragua-espanol,panama-espanol,paraguay-espanol,peru-espanol,puerto-rico-espanol,republica-dominicana-espanol,trinidad-tobago-english,united-states-english,united-states-espanol,uruguay-espanol,venezuela-espanol,europe,armenia-pyсский,austria-deutsch,azerbaijan-русский,belarus-pyсский,belgium-francais,belgium-nederlands',
#        '87500,france', 'usa', 'fort-worth,tx', 'allemagne', 'alicante',
#        'italy', 'good-organics-gmbh', 'rhone', '87500-saint-yrieix',
#        'france,87500', 'united-states', 'kenya', 'germany', 'mercadona',
#        'china', 'lyon', 'united-kingdon',
# ...

# %%
df.countries.isna().sum()
# Out:
# 348

# %%
df.countries.value_counts()
# Out:
# countries
# United States              20925
# en:us                       5454
# en:United States            4015
# en:fr                       2303
# us                          2181
#                            ...
# イタリア                           1
# Italy,en:switzerland           1
# en:Canada,                     1
# Martinique                     1
# United States,en:canada        1
# Name: count, Length: 732, dtype: int64

# %%
df.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'last_modified_by',
#        'last_updated_t', 'last_updated_datetime',
#        ...
#        'water-hardness_100g', 'choline_100g', 'phylloquinone_100g',
#        'beta-glucan_100g', 'inositol_100g', 'carnitine_100g', 'sulphate_100g',
#        'nitrate_100g', 'acidity_100g', 'carbohydrates-total_100g'],
#       dtype='object', length=209)

# %%
df_france = df[df['countries'].str.contains('france', case=False, na=False)].copy()
df_france.head()
# Out:
#     code                                                url  \
# 2    114  http://world-en.openfoodfacts.org/product/0000...
# 10     6  http://world-en.openfoodfacts.org/product/0000...
# 11  6666  http://world-en.openfoodfacts.org/product/0000...
# 20    15  http://world-en.openfoodfacts.org/product/0000...
# 22    17  http://world-en.openfoodfacts.org/product/0000...
#
#                        creator   created_t      created_datetime  \
# 2                      kiliweb  1580066482  2020-01-26T19:21:22Z
# 10                      maldan  1732037972  2024-11-19T17:39:32Z
# 11                  prepperapp  1709219541  2024-02-29T15:12:21Z
# 20  openfoodfacts-contributors  1523810594  2018-04-15T16:43:14Z
# 22                   foodvisor  1728736811  2024-10-12T12:40:11Z
#
#     last_modified_t last_modified_datetime last_modified_by  last_updated_t  \
# 2        1737247862   2025-01-19T00:51:02Z     smoothie-app      1743312145
# ...

# %%
df.emb_codes.unique()
# Out:
# array([nan, 'DE MV-006 EC', '13089c', 'CE', 'EMB 41106C,FR 41.108.001 EC',
#        'EMB 40168A', 'EMB 50267', '13084',
#        'www. boitiva. Good Organics Gmbh', '19HV0120/2-00312',
#        'LR12034B00', 'EMB 78291 B', '5255', 'FR 07.204.003 EC', '001100',
#        '491013', 'non renseigné', 'CT112307275', 'FSC-C020428',
#        'EMB 84092D', 'FSC C020428', '122120101', 'FSC-C128324',
#        'FSC-C017205', 'ce', 'EMB 13089C', 'FSC-C147479',
#        'FR 29.027.500 EC', 'EL 40 535', 'L067', 'FSC-C155613',
#        ' CO 80211 ', 'FSC-C014047', 'EMB 80302A', 'FSC-C123201',
#        'L:190618H', 'FR 72.264.002 EC', 'RNE 21-106529,RNPA 21-092262',
#        '002155', 'FR 12.223.001 EC,EMB 12223A', 'EMB 45270', '258151201',
#        'FSC-C095159', 'FR 01.336.002 EC', 'EMB 67194B',
#        'FR 31.090.010 EC', '3122co', 'FR 22.049.001 CE', 'DE BB-62070 EC',
#        'FSC-C012938', 'FSC-C115580', 'FR 56.017.001 EC',
#        '204071 390CC56.071-02', 'MSC-C-50472', 'FR-bio-01',
# ...

# %%
df.emb_codes.value_counts().sum()
# Out:
# 329

# %%
df.product_quantity.unique()
# Out:
# array([           nan, 8.00000000e+01, 2.80000000e+02, 7.50000000e+02,
#        4.00000000e+02, 7.00000000e+02, 1.00000000e+03, 2.30000000e+02,
#        5.00000000e+02, 0.00000000e+00, 4.50000000e+02, 8.30000000e+02,
#        3.00000000e+02, 2.50000000e+02, 1.08000000e+03, 5.90000000e+02,
#        2.60000000e+02, 6.10000000e+02, 9.00000000e+02, 1.00000000e+02,
#        6.00000000e+02, 4.90000000e+02, 1.50000000e+03, 4.53592370e+02,
#        7.80000000e+02, 7.89000000e+01, 6.60000000e+02, 3.50000000e+01,
#        9.20000000e+02, 2.26800000e+03, 3.00000000e+01, 2.10000000e+03,
#        5.44310844e+03, 2.00000000e+03, 7.50000000e+01, 5.00000000e+03,
#        5.00000000e+01, 1.99000000e+02, 5.50000000e+02, 2.00000000e+02,
#        8.50000000e+02, 1.70097139e+02, 4.55000000e+02, 5.10000000e+01,
#        5.60000000e+02, 1.25000000e+02, 1.40000000e+02, 7.40000000e+02,
#        7.39000000e+02, 8.50000000e+00, 4.54000000e+02, 8.00000000e+02,
# ...

# %%
df_cleaned = ['product_name, brand, quantity', 'last_image_','energy-kcal_100g','carbohydrates_100g', 'proteins_100g', 'fat_100g',
'first_packaging_code_geo', 'emb_codes_tags', 'emb_codes_tags',
'countries', 'countries_en', 'countries_tags', 'origins', 'origins_en', 'origins_tags', manufacturing_places, manufacturing_places_tags, first_packaging_code_geo, cities, cities_tags, purchase_places, stores
